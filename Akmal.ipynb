# %% [markdown]
# <a href="https://colab.research.google.com/github/TOBIANDA/9-Tobias-Akmal/blob/main/Akmal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Muhammad Akmal Baihaqii")
print("255150407111045")
# Out:
# Muhammad Akmal Baihaqii
# 255150407111045
