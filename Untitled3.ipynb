# %% [markdown]
# <a href="https://colab.research.google.com/github/TOBIANDA/9-Tobias-Akmal/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Using Colab cache for faster access to the 'chicago-crime-dataset-2024-2026' dataset.
# Path to dataset files: /kaggle/input/chicago-crime-dataset-2024-2026

# %%
import pandas as pd
import os

files = os.listdir(path)
print("File yang tersedia:", files)

file_path = os.path.join(path, files[0])

df = pd.read_csv(file_path)

print("Ukuran DataFrame:", df.shape)
# Out:
# File yang tersedia: ['chicago crimes.csv']
# /tmp/ipykernel_537/3118010949.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Ukuran DataFrame: (8500901, 22)
